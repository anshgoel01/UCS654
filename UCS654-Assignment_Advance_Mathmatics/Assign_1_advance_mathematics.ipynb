# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv", encoding="latin1")
x = df["no2"].dropna().values
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24504\931460200.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data.csv", encoding="latin1")

# %%
#given 
#   ar= 0.05 * ( r mod 7)
#   br= 0.3 * ( r mod 5 + 1)

r = 102317042

ar = 0.05 * ( r % 7)
br = 0.3 * ((r % 5) + 1)

z = x + ar * np.sin(br * x)

# %%
mu = np.mean(z)

variance = np.var(z)
lamb = 1 / (2 * variance)

c = np.sqrt(lamb / np.pi)

print("Value of mu   :",mu)
print("Value of lamb :",lamb)
print("Value of c    :",c)
# Out:
# Value of mu   : 25.819751672076492
# Value of lamb : 0.0014619269889668285
# Value of c    : 0.02157187552038633
